# %%
import pandas as pd

# %%
path1 = '/Users/eorlov002/Documents/repo/gpt_wrap/gpt_wrap/articles/first_part_articles.parquet'
tax_article1 = pd.read_parquet(path1)

path2 = '/Users/eorlov002/Documents/repo/gpt_wrap/gpt_wrap/articles/second_part_articles.parquet'
tax_article2 = pd.read_parquet(path2)

# %%
tax_article2.reset_index(drop=True)
# Out:
#      paragraph subparagraph
# 0           1.               \
# 1           2.
# 2           1.
# 3           2.
# 4           3.
# ...        ...          ...
# 6515       15.
# 6516        1.
# 6517        2.
# 6518        3.
# 6519        4.
#
#                                                 content
# 0     Налогоплательщиками налога на добавленную стои...  \
# 1     Утратил силу с 1 января 2017 года. - Федеральн...
# 2     Организации и индивидуальные предприниматели, ...
# 3     Положения настоящей статьи не распространяются...
# 4     Освобождение в соответствии с пунктом 1 настоя...
# ...                                                 ...
# 6515  В случае прекращения деятельности организации ...
# 6516  Исчисление суммы страховых взносов, подлежащих...
# 6517  Абзац утратил силу с 1 января 2023 года. - Фед...
# 6518  Главы крестьянских (фермерских) хозяйств предс...
# 6519  Физические лица, прекратившие деятельность в к...
#
# ...

# %%
tax_article1
# Out:
#      paragraph subparagraph
# 0           1.               \
# 1           2.
# 2           2.           1)
# 3           2.           2)
# 4           2.           3)
# ...        ...          ...
# 2230        2.
# 2231        3.
# 2232        1.
# 2233        1.
# 2234        2.
#
#                                                 content
# 0     Законодательство Российской Федерации о налога...  \
# 1     Настоящий Кодекс устанавливает систему налогов...
# 2     виды налогов и сборов, взимаемых в Российской ...
# 3     основания возникновения (изменения, прекращени...
# 4     принципы установления, введения в действие и п...
# ...                                                 ...
# 2230  Федеральный орган исполнительной власти, уполн...
# 2231  Порядок передачи страновых отчетов компетентны...
# 2232  Информация из страновых отчетов, представляема...
# 2233  Порядок проведения взаимосогласительной процед...
# 2234  Взаимосогласительная процедура может быть иниц...
#
# ...
